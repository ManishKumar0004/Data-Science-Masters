# %% [markdown]
# #   &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; Assignment

# %% [markdown]
# ### Q1. What are the three measures of central tendency?
# ### Ans :-
# **Central tendency and variation are two measures used in statistics to summarize data. Measure of central tendency shows where the center or middle of the data set is located, whereas measure of variation shows the dispersion among data values.**

# %% [markdown]
# ### (i) Measures of Central Tendency :
# **It represents the whole set of data by a single value. It gives us the location of the central points. measures of central tendency are sometimes called measures of central location.They are also classed as summary statistics.<br>The mean, median and mode are the three commonly used measures of central tendency.**

# %% [markdown]
# ### MEAN

# %% [markdown]
# **Mean in general terms is used for the arithmetic mean of the data.The mean represents the average value of the dataset. It can be calculated as the sum of all the values in the dataset divided by the number of values. It can be used with both discrete and continuous data, although its use is most often with continuous data.**
#
# **There are different types of mean :<br>**
# **Geometric Mean<br>**
# **Harmonic Mean<br>**
# **Weighted Mean**

# %% [markdown]
# ### Arithmetic Mean :
# **Arithmetic mean (or, simply, “mean”) is nothing but the average.It can be calculated as the sum of all the values in the dataset divided by the number of values. It can be used with both discrete and continuous data, although its use is most often with continuous data.**

# %% [markdown]
# **The formula to calculate the mean value is given by:**

# %% [markdown]
# ![image.png](attachment:001eb7d2-9ed9-422e-9e17-554d10f6a9bc.png)

# %% [markdown]
# **the sample mean, usually pronounced as "x bar".**

# %% [markdown]
# ### Sample mean formula
# **The sample mean is written as M or x̄ (pronounced x-bar). For calculating the mean of a sample, use this formula:**

# %% [markdown]
# ![image.png](attachment:864851e4-5e70-498a-b084-d892f60698ee.png)

# %% [markdown]
# **x̄ :  sample mean<br>**
# **Σx : sum of all values in the sample dataset<br>**
# **n : number of values in the sample dataset**

# %% [markdown]
# **Example: If there are 5 observations, which are 27, 11, 17, 19, and 21 then the mean is given by**
#
# **mean = (27 + 11 + 17 + 19 + 21) ÷ 5<br>**
#
# **⇒ mean = 95 ÷ 5<br>**
#
# **⇒ mean = 19**

# %% [markdown]
# ### Population mean formula
# **The population mean is written as μ (Greek term mu). For calculating the mean of a population, use this formula:**

# %% [markdown]
# ![image.png](attachment:7436ae29-468c-4662-ac91-9a76e4907203.png)

# %% [markdown]
# **μ : population mean<br>**
# **Σx : sum of all values in the population dataset<br>**
# **N : number of values in the population dataset**

# %% [markdown]
# ### Mean for Grouped Data
# **Mean ( x̄ ) is defined for the grouped data as the sum of the product of observations (xi) and their corresponding frequencies (fi) divided by the sum of all the frequencies (fi)**.

# %% [markdown]
# ![image.png](attachment:cb631d88-61c7-42b3-b978-994e928d4568.png)

# %% [markdown]
# ### Geometric Mean :
# **It is defined as the arithmetic mean of the values taken on a log scale. It is also expressed as the nth root of the product of an observation.**

# %% [markdown]
# ![image.png](attachment:2e4147f3-16c1-4b96-bf45-84bf246f41ee.png)

# %% [markdown]
# ### Harmonic mean :
# **It is the reciprocal of the arithmetic mean of the observations.**

# %% [markdown]
# ![image.png](attachment:2bdfa3a5-7565-44b5-a46e-b9cfdb764c7d.png)

# %% [markdown]
# ### Median :
# **It is the middle value of the data set. It splits the data into two halves. If the number of elements in the data set is odd then the center element is the median and if it is even then the median would be the average of two central elements.**

# %% [markdown]
# ### Median of an odd-numbered dataset :
# ### Formula

# %% [markdown]
# ![image.png](attachment:b1d2f4eb-786d-4547-b439-939493adaa67.png)

# %% [markdown]
# ### Example :
# **You measure the reaction times in milliseconds of 5 participants and order the dataset.<br>**
#
# **`Reaction time (milliseconds)` :  287, 298, 345, 365, 380<br>**
#
# **The middle position is calculated using<br>**
# \begin{equation*}\dfrac{(n+1)}{2}\end{equation*} , **where n = 5**.<br>
#
#   \begin{equation*}\dfrac{(5+1)}{2}=3\end{equation*}
# **That means the median is the 3rd value in your ordered dataset.<br>**
#
# **`Median `: 345 milliseconds**

# %% [markdown]
# ### Median of an even-numbered dataset :
# ### Formula

# %% [markdown]
# ![image.png](attachment:7c91784c-0850-4a91-8198-837fd2ff8035.png)

# %% [markdown]
# ### Example
# **You measure the reaction times of 6 participants and order the dataset.<br>**
#
# **`Reaction time (milliseconds)` :	287, 298, 345, 357, 365, 380 <br>**
# **The middle positions are calculated using <br>**
# \begin{equation*}\dfrac{n}{2}\end{equation*} and  \begin{equation*}(\dfrac{n}{2})+1\end{equation*},
# **where n = 6 <br>**
#
#   \begin{equation*}\dfrac{6}{2}=3\end{equation*}
#   \begin{equation*}(\dfrac{6}{2})+1=4\end{equation*}
#
# **That means the middle values are the 3rd value, which is 345, and the 4th value, which is 357.<br>**
#
# **To get the median, take the mean of the 2 middle values by adding them together and dividing by 2.<br>**
#
#   \begin{equation*}\dfrac{(345+357)}{2}=351\end{equation*}
# **`Median`: 351 milliseconds**

# %% [markdown]
# ### Mode :
# **It is the value that has the highest frequency in the given data set. The data set may have no mode if the frequency of all data points is the same. Also, we can have more than one mode if we encounter two or more data points having the same frequency.<br>**
# **To find the mode, sort your dataset numerically or categorically and select the response that occurs most frequently.**

# %% [markdown]
# ### Mode of Ungrouped Data
# **Mode of Ungrouped Data can be simply calculated by observing the observation with the highest frequency.<br>**
# **Let’s see an example of the calculation of the mode of ungrouped data.<br>**
# **The mode of the data set is the highest frequency term in the data set as shown in the image added below.**

# %% [markdown]
# ![image.png](attachment:423052a9-6a51-494d-a199-897c3f070b70.png)

# %% [markdown]
# **Since 3 has occurred a maximum number of times i.e. 4 times in the given data<br>**
# **Hence, Mode of the given ungrouped data is 3.**

# %% [markdown]
# ### Mode of Grouped Data
# **The formula to find the mode of the grouped data is:**

# %% [markdown]
# ![image.png](attachment:cc48c9be-cc8b-4da9-9123-0a588b2eb323.png)

# %% [markdown]
# ### Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?
# ### Ans :-
# ### Difference between the mean, median, and mode are :

# %% [markdown]
# <table>
#   <tr>
#     <th>Sl. No.</th>
#     <th>Mean</th>
#     <th>Median</th>
#     <th>Mode</th>
#   </tr>
#   <tr>
#     <td>1.</td>
#     <td>The average taken for a set of numbers is called a mean.</td>
#     <td>The middle value in the data set is called the Median.</td>
#     <td>The number that occurs the most in a given list of numbers is called a mode.</td>
#   </tr>
#   <tr>
#     <td>2.</td>
#     <td>Add all of the numbers together and divide the sum by the total number of values.</td>
#     <td>Place all the given numbers in an ascending order</td>
#     <td>It shows the frequency of occurrence.</td>
#   </tr>
#   <tr>
#     <td>3.</td>
#     <td>The result is the mean or average score.</td>
#     <td>The next step is to find the middle number on the list. It is called the median.</td>
#     <td>We can have more than one mode or no mode at all.</td>
#   </tr>
#   <tr>
#     <td>4.</td>
#     <td>Example: To find the average of the four numbers 2, 4, 6, and 8, we need to add the number first. 2 + 4 + 6 + 8 = 20 Divide the sum by the total number of numbers, i.e., 4. 20/4 = 5 is the average or mean</td>
#     <td>Example: 4, 2, 8, 10, 19. Arrange the numbers in ascending order. i.e., 2, 4, 8, 10, 19. As the total numbers are 5, so the middle number 8 is the median here.</td>
#     <td>Example: 3, 3, 5, 6, 7, 7, 8, 1, 1, 1, 4, 5, 6. Find the frequency of each number. For number 3, it’s 2. For 5, it’s 2. For 6, it’s 2. For 7, it’s 2. For 8, it’s one. For 1, it’s 3. For 4, it’s 1. The number with the highest frequency is the mode. Hence, the mode of the given sequence of numbers is 1.</td>
#   </tr>
#   <tr>
#     <td>5.</td>
#     <td>The mean is generally preferred when the data are normally distributed.</td>
#     <td>The median is the most accurate representation when the data distribution is skewed.</td>
#     <td>The mode is preferred when there is a nominal distribution of the data.</td>
#   </tr>
# </table>

# %% [markdown]
# ## Distributions and Central Tendency
# **A data set in central tendency is a distribution of n number of records or values. <br>Distributions are basically of 2 types:**

# %% [markdown]
# ### Normal Distribution:
# **In a normal distribution(symmetric distribution), information or data is symmetrically distributed with no skew. Most of the values cluster around a central area, with values decreasing off as they travel away from the center. The mean, mode and median are the same in a normal distribution.**

# %% [markdown]
# ![image.png](attachment:778540df-f89d-435c-9534-e91328c65769.png)

# %% [markdown]
# ### Skewed Distributions :
# **In skewed distributions, most of the values lie on one side of the center rather than the other, and the mean, median and mode all vary from one another. The direction of this tail shows us the side of the skew.<br>**
#
# - **If Right-skewed or positively skewed, the tail reaches out to the right.<br>**
# - **Mean > median > mode**

# %% [markdown]
# ![image.png](attachment:9d962f63-7613-4c96-8130-3bdf51a2e08a.png)

# %% [markdown]
# - **Left-skewed or negatively skewed, the tail reaches out to the left.<br>**
# - **Mode > median > mean**

# %% [markdown]
# ![image.png](attachment:68f20225-6a56-45e2-9742-bf7c9d376cc9.png)

# %% [markdown]
# **The shape of the data helps us to determine the most appropriate measure of central tendency. The three most significant descriptions of shape are symmetric, left-skewed, and right-skewed. Skewness is a measure of the degree of asymmetry of the distribution.**

# %% [markdown]
# ### Q3. Measure the three measures of central tendency for the given height data:
# ###     [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]
# ### Ans :-

# %%
import numpy as np
from scipy import stats

height_data = [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]

mean_height = np.mean(height_data)

median_height = np.median(height_data)

mode_height = stats.mode(height_data)


print("Mean height:", mean_height)
print("Median height:", median_height)
print("Mode height:", mode_height)
# Out:
# Mean height: 177.01875
# Median height: 177.0
# Mode height: ModeResult(mode=177.0, count=3)

# %% [markdown]
# ### Explanation :
# - **In NumPy, np.mean() function calculates the arithmetic mean , the median is calculating using np.median(), and the mode using stats.mode() from the SciPy library, which sorts the array and finds the most frequently occurring value.**

# %% [markdown]
# ### Q4. Find the standard deviation for the given data:
# ### [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %% [markdown]
# ### Ans :-

# %%
import numpy as np

data = [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]

std_dev = np.std(data)

print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 1.7885814036548633

# %% [markdown]
# ### Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example ?
# ### Ans :-

# %% [markdown]
# ### Measures of Variability :
# - **In statistics, the variability is also known as dispersion, scatter, or spread. It explains the variation in data values in terms of distribution, which tells us how far the data value falls from the center.<br>**
#
# - **A low dispersion represents the data clustered around a center, while high dispersion indicates the widely spread data from the center.**

# %% [markdown]
# #### There are many ways to describe variability or spread including:
#
# **Variance <br>**
# **Standard Deviation**

# %% [markdown]
# ### Variance :
# **It is defined as an average squared deviation from the mean. It is calculated by finding the difference between every data point and the average which is also known as the mean, squaring them, adding all of them, and then dividing by the number of data points present in our data set.**

# %% [markdown]
# **There are two formulas for the variance depending on whether you are calculating the variance for an entire population or using a sample to estimate the population variance.**

# %% [markdown]
# ![image.png](attachment:0daccb78-0c0e-431b-8c5c-c2d3b3c4e7b7.png)

# %% [markdown]
# ![image.png](attachment:5f6bc165-b3e1-479b-8a18-fcc5a308fbdf.png)

# %% [markdown]
# ### Standard Deviation :
# - **The standard deviation is the standard or typical difference between each data point and the mean. When the values in a dataset are grouped closer together, you have a smaller standard deviation. On the other hand, when the values are spread out more, the standard deviation is larger because the standard distance is greater.<br>**
#
# - **The standard deviation is just the square root of the variance.**

# %% [markdown]
# ![image.png](attachment:525830d4-e6f9-4474-873b-429f48ce9c99.png)

# %% [markdown]
# ![image.png](attachment:8d904457-86f0-488d-9a3e-c652adf1bf82.png)

# %% [markdown]
# ### Normal distributions
# **The normal distribution is the most important and commonly used distribution in statistics. It is also known as the bell curve or Gaussian curve. Even though normal distributions can differ in their means and standard deviation, they share some characteristics related to the distribution of scores:<br>**
#
# - **they are symmetric around their mean<br>**
# - **the mean, median, and mode are equal<br>**
# - **are denser in the center and less dense in the tails<br>**
# - **are defined by two parameters: the mean and standard deviation<br>**
# - **68% of the area is within one standard deviation of the mean<br>**
# - **approximately 95% of the area is within two standard deviations of the mean<br>**
# - **99.7 % of the area is within 3 standard deviations of the mean.**

# %% [markdown]
# ### The 68-95-99.7% rule
#
# **Standard normal deviations follow the 68-95-99.7% rule:**

# %% [markdown]
# ![image.png](attachment:821a4e87-285b-4557-bb50-a6b0315686c1.png)

# %% [markdown]
# - **68% of scores are within one standard deviation of the mean.<br>**
# - **95% of scores are within 2 standard deviations of the mean.<br>**
# - **99.7% of scores are within 3 standard deviations of the mean.**

# %% [markdown]
# ## Example :

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data1 = [172.5, 175. , 175. , 176. , 176.2, 176.5, 177. , 177. , 178. ,178. , 178. , 178.2, 178.9, 179. , 180.]
data2 = [172.5, 172.9, 172.9, 175. , 175.5, 175.2, 175.9 , 176., 177. , 178. , 178. , 178., 179. , 180.]

sns.displot(data1, kde=True, rug=True, height=3, aspect=1)
sns.displot(data2, kde=True, rug=True, height=3, aspect=1)

# Show plot
plt.show()

# %%
import numpy as np

print("Data1:")
print("Mean:", np.mean(data1))
print("Variance:", np.var(data1))
print("Standard Deviation:", np.std(data1))

print("\nData2:")
print("Mean:",np.mean(data2))
print("Variance:", np.var(data2))
print("Standard Deviation:", np.std(data2))
# Out:
# Data1:
# Mean: 177.02
# Variance: 3.4122666666666674
# Standard Deviation: 1.8472321637159383
#
# Data2:
# Mean: 176.13571428571427
# Variance: 5.0794387755102
# Standard Deviation: 2.2537610289270242

# %% [markdown]
# ## Explanation :-

# %% [markdown]
# ### In context to Variance :
# - **We can see that when the variance is a big number, the spread of data is increasing, and when the variance is a small number, the spread of data is decreasing, and the height of the curve is also increasing when it is small.<br>**

# %% [markdown]
# ### In context to Standard Deviation :
# - **SD is basically the deviation from the central tendencay of distribution of random variable(here mean). So this means more the value of SD more will be the chances of observation to lie far from central tendency of distribution. And hence spread will be more for that distribution.**
# - **In the distribution of data1, whatever elements are present between 177.02 and 178.86 will be falling within 1st Standard Deviation towards the right and any elements that present between 177.02 and 175.18 will be falling 1st Standard Deviation towards the left.It helps to understand that between 1st std to the right and left , what may be the range of data that may be falling**
# - **Similar to data2**

# %% [markdown]
# ### Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
# \begin{equation*}(i)  A \cap B\end{equation*}
# \begin{equation*}(ii)  A \cup B\end{equation*}

# %% [markdown]
# ### Ans :-
# ### What are Sets?
#
# - **In mathematics, a set is a collection of distinct objects, called elements, that are considered as a whole. These objects can be anything: numbers, letters, shapes, or even other sets.<br>**
#  - **Sets are defined by listing their elements inside curly braces. For example, a set of numbers {1, 2, 3} represents a collection of the numbers 1, 2, and 3.<br>**

# %% [markdown]
# ### Union of Set
# **Union of sets is the set of elements which are a combination of elements that are present in both the given sets.<br>**
# \begin{equation*}Symbol-->  A \cup B\end{equation*}
# ### Intersection of Sets
# **Intersection of sets is the set of elements which are common to both the given sets.**
# \begin{equation*}Symbol-->  A \cap B\end{equation*}

# %%
# Given sets
A = {2, 3, 4, 5, 6, 7}
B = {0, 2, 6, 8, 10}


intersection = A.intersection(B)
print("Intersection of A and B:", intersection)

union = A.union(B)
print("Union of A and B:", union)
# Out:
# Intersection of A and B: {2, 6}
# Union of A and B: {0, 2, 3, 4, 5, 6, 7, 8, 10}

# %% [markdown]
# ### Q8. What do you understand about skewness in data?
# ### Ans :-

# %% [markdown]
# ### What Is Skewness?
# - **Skewness is a measure of the asymmetry or lack of symmetry in a data distribution.A distribution is asymmetrical when its left and right side are not mirror images.A distribution can have right (or positive), left (or negative), or zero skewness. A right-skewed distribution is longer on the right side of its peak, and a left-skewed distribution is longer on the left side of its peak.<br>**
#
# - **In other words, skewness is the measure of how much the probability distribution of a random variable deviates from the normal distribution. Skewness is demonstrated on a bell curve when data points are not distributed symmetrically to the left and right sides of the median on a bell curve. If the bell curve is shifted to the left or the right, it is said to be skewed.**
# - **Skewness tells you where the outliers occur, although it doesn't tell you how many outliers occur.**.

# %% [markdown]
# ### What is zero skew?
# - **When a distribution has zero skew, it is symmetrical. Its left and right sides are mirror images.Normal distributions have zero skew, but they’re not the only distributions with zero skew.**

# %% [markdown]
# #### Normal distributions :
# **The normal distribution is the most important and commonly used distribution in statistics. It is also known as the bell curve or Gaussian curve. Even though normal distributions can differ in their means and standard deviation, they share some characteristics related to the distribution of scores:<br>**

# %% [markdown]
# ![image.png](attachment:778540df-f89d-435c-9534-e91328c65769.png)

# %% [markdown]
# - **they are symmetric around their mean<br>**
# - **the mean, median, and mode are equal<br>**
# - **are denser in the center and less dense in the tails<br>**
# - **are defined by two parameters: the mean and standard deviation<br>**
# - **68% of the area is within one standard deviation of the mean<br>**
# - **approximately 95% of the area is within two standard deviations of the mean<br>**
# - **99.7 % of the area is within 3 standard deviations of the mean.**

# %% [markdown]
# ### The 68-95-99.7% rule
#
# **Standard normal deviations follow the 68-95-99.7% rule:**

# %% [markdown]
# ![image.png](attachment:821a4e87-285b-4557-bb50-a6b0315686c1.png)

# %% [markdown]
# - **68% of scores are within one standard deviation of the mean.<br>**
# - **95% of scores are within 2 standard deviations of the mean.<br>**
# - **99.7% of scores are within 3 standard deviations of the mean.**

# %% [markdown]
# ### Types of skewness:
# **In skewed distributions, most of the values lie on one side of the center rather than the other, and the mean, median and mode all vary from one another. The direction of this tail shows us the side of the skew.**
#
# **There are two types of skewness:**
# - **Positive Skewness**
# - **Negative Skewness**

# %% [markdown]
# ### Positive Skewness :

# %% [markdown]
# - **If the given distribution is shifted to the left and with its tail on the right side, it is a positively skewed distribution. It is also called the right-skewed distribution.<b r>**
# - **You can think of skewness in terms of tails.A right-skewed distribution has a long tail on its right side.**
# - **If Right-skewed or positively skewed, the tail reaches out to the right.<br>**
# - **Mean > median > mode**

# %% [markdown]
# ![image.png](attachment:9d962f63-7613-4c96-8130-3bdf51a2e08a.png)

# %% [markdown]
# ### Negative Skewness :

# %% [markdown]
# - **If the given distribution is shifted to the right and with its tail on the left side, it is a negatively skewed distribution. It is also called a left-skewed distribution.<br>**
# - **In other words, a left-skewed distribution has a long tail on its left side.**
# - **Left-skewed or negatively skewed, the tail reaches out to the left.<br>**
# - **Mode > median > mean**

# %% [markdown]
# ![image.png](attachment:68f20225-6a56-45e2-9742-bf7c9d376cc9.png)

# %% [markdown]
# ### Measuring Skewness :
# **There are two common methods to measure skewness.**
# - **Pearson’s First Coefficient**
# - **Pearson’s Second Coefficient**

# %% [markdown]
# ### Pearson’s First Coefficient :
# - **Pearson’s first coefficient of skewness, or Pearson mode skewness, subtracts the mode from the mean and divides the difference by the standard deviation.**

# %% [markdown]
# ### Formula :-

# %% [markdown]
# ![image.png](attachment:75273461-a197-4216-ab96-63dd1c19996c.png)

# %% [markdown]
# ### Pearson’s Second Coefficient :
# - **Pearson’s second coefficient of skewness, or Pearson median skewness, subtracts the median from the mean, multiplies the difference by three, and divides the product by the standard deviation.**

# %% [markdown]
# ### Formula :-

# %% [markdown]
# ![image.png](attachment:fe523b84-b9d3-4a0a-97ee-08530ac03db1.png)

# %% [markdown]
# ### Q9. If a data is right skewed then what will be the position of median with respect to mean?
# ### Ans :-

# %% [markdown]
# **If a dataset is right-skewed, it means that the tail of the distribution extends towards the right side, indicating that there are a few very large values that pull the mean in that direction.<br>**
# **In a right-skewed distribution:<br>**
# - **The mean will be greater than the median.<br>**
# - **The median will be less than the mean.<br>**
#
# **Therefore, in a right-skewed distribution, the median will be positioned to the left of the mean.**

# %% [markdown]
# ### Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?
# ### Ans :- Covariance and Correlation

# %% [markdown]
# ### Covariance :

# %% [markdown]
# **covariance and correlation measure the relationship and the dependency between two variables.<br> Covariance indicates the direction of the linear relationship between variables while correlation measures <br>both the strength and direction of the linear relationship between two variables. Correlation is a function of <br>the covariance.
# Correlation values are standardized whereas covariance values are not.**

# %% [markdown]
# ### HOW TO CALCULATE COVARIANCE
# ### `Population Covariance Formula` :

# %% [markdown]
# ![image.png](attachment:082f7836-a870-4dca-8a35-4b9f271501d2.png)

# %% [markdown]
# - **xi = data value of x<br>**
# - **yi = data value of y<br>**
# - **x̄ = mean of x<br>**
# - **ȳ = mean of y<br>**
# - **N = number of data values<br>**

# %% [markdown]
# ### `Sample Covariance Formula` :

# %% [markdown]
# ![image.png](attachment:82bacf97-b025-4f08-bfdf-1f7c9a40f9f4.png)

# %% [markdown]
# **The value (n-1) indicates the degrees of freedom.
# Degrees of freedom is the number of independent data points that went into calculating the estimat**e.

# %% [markdown]
# ### Interpreting Covariance Values :
# **Covariance values indicate the magnitude and direction (positive or negative) of the relationship between variables. The covariance values range from `-∞ to +∞`. The positive value implies a positive relationship, whereas the negative value represents a negative relationship.Zero Covariance indicates no relationship between two variables.**

# %% [markdown]
# ### Types of covariance :

# %% [markdown]
# ### Positive covariance :
# **A positive number represents Positive Covariance means both the variables (X, Y) move in the same direction.Means that when value of x is increasing then y is also increasing. Similar, when x is decreasing then y is also decreasing.**
# **This tells you something about the linear relationship between the two variables. So, for example, if an increase in a person’s height corresponds with an increase in a person’s weight, there is positive covariance between the two.**

# %% [markdown]
# ###  &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;↑X⟹↑Y
# ###  &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;↓X⟹↓Y

# %% [markdown]
# ### Negative covariance :
# **A negative number represents negative Covariancee means both the variables (X, Y) move in the opposite direction Means that when value of x is increasing then y is decreasing. Similar, when x is increasing then y is also increasing.**.

# %% [markdown]
# ###  &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;↑X⟹↓Y
# ###  &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;↓X⟹↑Y

# %% [markdown]
# ### Zero Covariance :
# **Zero Covariance indicates no relationship between two variables.**

# %% [markdown]
# ### Correlation :

# %% [markdown]
# **covariance and correlation measure the relationship and the dependency between two variables.<br> Covariance indicates the direction of the linear relationship between variables while correlation measures <br>both the strength and direction of the linear relationship between two variables. Correlation is a function of <br>the covariance.
# Correlation values are standardized whereas covariance values are not.<br>**
# **The correlation values range from -1 to +1.<br>**
# **The main result of a correlation is called the correlation coefficient.**
# ## Methods of Calculating Correlation
# ### Pearson Correlation coefficient :

# %% [markdown]
# **Correlation is calculated using a method known as “Pearson’s Product-Moment Correlation” or simply “Correlation Coefficient.”<br>**
# **The Pearson correlation coefficient (r) is the most common way of measuring a linear correlation. It is a number between –1 and 1 that measures the strength and direction of the relationship between two variables.<br>**
#
# **`Disadvantage of Pearson` : It is not able to capture the non-linear properties.In order to overcome to this problem we use Spearman Correlation Coefficient**

# %% [markdown]
# ### Formula :

# %% [markdown]
# ![image.png](attachment:3c06d065-777b-4a9d-82e3-0d7c2015a6c7.png)

# %% [markdown]
# ### Spearman’s Rank Correlation:
# **It’s a nonparametric indicator of rank correlation or the statistical dependency between the ranks of two variables. It evaluates how effectively a monotonic function can capture the connection between two variables.<br>**
# **It basically gives the measure of monotonicity of the relation between two variables i.e. how well the relationship between two variables could be represented using a monotonic function.**

# %% [markdown]
# - **Monotonically Increasing: As the variable X increases, the variable Y never decreases.<br>**
# - **Monotonically Decreasing: As the variable X increases, the variable Y never increases.<br>**
# - **Not Monotonic: As the X variable increases, the Y variable sometimes decreases and sometimes increases.**

# %% [markdown]
# ### Formula :-

# %% [markdown]
# ![image.png](attachment:467aca90-fef7-4453-bd4e-7174f0b1fa6e.png)

# %% [markdown]
# ## The difference between covariance and correlation are :

# %% [markdown]
# | Covariance                                                       | Correlation                                                         |
# |------------------------------------------------------------------|---------------------------------------------------------------------|
# | Covariance is a measure to indicate the extent to which two random variables change in tandem. | Correlation is a measure used to represent how strongly two random variables are related to each other. |
# | Covariance is nothing but a measure of correlation.             | Correlation refers to the scaled form of covariance.                 |
# | Covariance indicates the direction of the linear relationship between variables. | Correlation, on the other hand, measures both the strength and direction of the linear relationship between two variables. |
# | Covariance can vary between -∞ and +∞.                          | Correlation ranges between -1 and +1.                                 |
# | Covariance is affected by the change in scale. If all the values of one variable are multiplied by a constant and all the values of another variable are multiplied by a similar or different constant, then the covariance is changed. | Correlation is not influenced by the change in scale.                 |
# | Covariance assumes the units from the product of the units of the two variables. | Correlation is dimensionless, i.e., it’s a unit-free measure of the relationship between variables. |
# | Covariance of two dependent variables measures how much in real quantity (i.e., cm, kg, liters) on average they co-vary. | Correlation of two dependent variables measures the proportion of how much on average these variables vary with respect to one another. |
# | Covariance is zero in the case of independent variables (if one variable moves and the other doesn’t) because then the variables do not necessarily move together. | Independent movements do not contribute to the total correlation. Therefore, completely independent variables have a zero correlation. |

# %% [markdown]
# ## Application of Covariance vs. Correlation in Analytics

# %% [markdown]
# - **Correlation analysis, as a lot of analysts know, is a vital tool for feature selection and multivariate analysis in data preprocessing and exploration. Correlation helps us investigate and establish relationships between variables, a strategy we employ in feature selection before any kind of statistical modeling or data analysis.**
#
# - **PCA (Principal Component Analysis) is a significant application of correlations between variables. We need to study the relationships between the variables involved in a dataset, to be able to create new variables that can reduce the number of original values, without compromising on the information contained in them. The new variables, also called principal components are formed on the basis of correlations between the existing original variables. So how do we decide what to use: the correlation matrix or the covariance matrix? Put simply, you should use the covariance matrix when the variables are on similar scales and the correlation matrix when the variables’ scales differ.**

# %% [markdown]
# ### Q11. What is the formula for calculating the sample mean? Provide an example calculation for a dataset. ?
# ### Ans :-

# %% [markdown]
# ### MEAN

# %% [markdown]
# **Mean in general terms is used for the arithmetic mean of the data.The mean represents the average value of the dataset. It can be calculated as the sum of all the values in the dataset divided by the number of values. It can be used with both discrete and continuous data, although its use is most often with continuous data.**
#
# **There are different types of mean :<br>**
# **Geometric Mean<br>**
# **Harmonic Mean<br>**
# **Weighted Mean**

# %% [markdown]
# ### Arithmetic Mean :
# **Arithmetic mean (or, simply, “mean”) is nothing but the average.It can be calculated as the sum of all the values in the dataset divided by the number of values. It can be used with both discrete and continuous data, although its use is most often with continuous data.**

# %% [markdown]
# **The formula to calculate the mean value is given by:**

# %% [markdown]
# ![image.png](attachment:001eb7d2-9ed9-422e-9e17-554d10f6a9bc.png)

# %% [markdown]
# **the sample mean, usually pronounced as "x bar".**

# %% [markdown]
# ### Sample mean formula
# **The sample mean is written as M or x̄ (pronounced x-bar). For calculating the mean of a sample, use this formula:**

# %% [markdown]
# ![image.png](attachment:864851e4-5e70-498a-b084-d892f60698ee.png)

# %% [markdown]
# **x̄ :  sample mean<br>**
# **Σx : sum of all values in the sample dataset<br>**
# **n : number of values in the sample dataset**

# %% [markdown]
# ### How to calculate the sample mean

# %% [markdown]
# ### 1. Add up the sample items
# **First, you will need to count how many sample items you have within a data set and add up the total amount of items. Let's look at an example:<br>**
#
# **Example: A teacher wants to find the average score for a student in his class. The teacher's sample set has seven different test scores: 78, 89, 93, 95, 88, 78, 95. He adds all the scores together and gets a sum of 616. He can use this sum in the next step to find his sample mean.**

# %% [markdown]
# ### 2. Divide sum by the number of samples
# **Next, divide the sum by the total number of items in the data set. Using the teacher as an example, here is what this looks like:<br>**
#
# **Example: The teacher uses the sum of 616 to find the average score. He divides 616 by seven since the number of scores in his data set was seven. The resulting quotient is 88.**

# %% [markdown]
# ### 3. The result is the mean
# **After dividing, the resulting quotient becomes your sample mean, or average. In the example of the teacher:<br>**
#
# **Example: The student's scores he was calculating resulted in an average grade of 88%. You can use the sample mean to further calculate variance, standard deviation and standard error.**

# %% [markdown]
# ### Q12. For a normal distribution data what is the relationship between its measure of central tendency?
# ### Ans :-

# %% [markdown]
# #### Normal distributions :
# **The normal distribution is the most important and commonly used distribution in statistics. It is also known as the bell curve or Gaussian curve. Even though normal distributions can differ in their means and standard deviation, they share some characteristics related to the distribution of scores:<br>**

# %% [markdown]
# ![image.png](attachment:778540df-f89d-435c-9534-e91328c65769.png)

# %% [markdown]
# - **they are symmetric around their mean<br>**
# - **the mean, median, and mode are equal<br>**
# - **are denser in the center and less dense in the tails<br>**
# - **are defined by two parameters: the mean and standard deviation<br>**
# - **68% of the area is within one standard deviation of the mean<br>**
# - **approximately 95% of the area is within two standard deviations of the mean<br>**
# - **99.7 % of the area is within 3 standard deviations of the mean.**

# %% [markdown]
# ### The 68-95-99.7% rule
#
# **Standard normal deviations follow the 68-95-99.7% rule:**

# %% [markdown]
# ![image.png](attachment:821a4e87-285b-4557-bb50-a6b0315686c1.png)

# %% [markdown]
# - **68% of scores are within one standard deviation of the mean.<br>**
# - **95% of scores are within 2 standard deviations of the mean.<br>**
# - **99.7% of scores are within 3 standard deviations of the mean.**

# %% [markdown]
# ### Q13. How is covariance different from correlation?
# ### Ans :-

# %% [markdown]
# ## The difference between covariance and correlation are :

# %% [markdown]
# | Covariance                                                       | Correlation                                                         |
# |------------------------------------------------------------------|---------------------------------------------------------------------|
# | Covariance is a measure to indicate the extent to which two random variables change in tandem. | Correlation is a measure used to represent how strongly two random variables are related to each other. |
# | Covariance is nothing but a measure of correlation.             | Correlation refers to the scaled form of covariance.                 |
# | Covariance indicates the direction of the linear relationship between variables. | Correlation, on the other hand, measures both the strength and direction of the linear relationship between two variables. |
# | Covariance can vary between -∞ and +∞.                          | Correlation ranges between -1 and +1.                                 |
# | Covariance is affected by the change in scale. If all the values of one variable are multiplied by a constant and all the values of another variable are multiplied by a similar or different constant, then the covariance is changed. | Correlation is not influenced by the change in scale.                 |
# | Covariance assumes the units from the product of the units of the two variables. | Correlation is dimensionless, i.e., it’s a unit-free measure of the relationship between variables. |
# | Covariance of two dependent variables measures how much in real quantity (i.e., cm, kg, liters) on average they co-vary. | Correlation of two dependent variables measures the proportion of how much on average these variables vary with respect to one another. |
# | Covariance is zero in the case of independent variables (if one variable moves and the other doesn’t) because then the variables do not necessarily move together. | Independent movements do not contribute to the total correlation. Therefore, completely independent variables have a zero correlation. |

# %% [markdown]
# ### Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.?
# ### Ans :-

# %% [markdown]
# ### Outliers can significantly affect measures of central tendency and dispersion :

# %% [markdown]
# ### For  measures of central tendency :

# %% [markdown]
# ### Mean:
# **When a outlier is present it can effect the shape of the graph, if we have outliers to the right of the graph. These outliers are causing the mean to increase, but if we have outliers to the left of the graph these outliers are dragging down the mean. This causes a conflict because the mean no longer provides a good representation of the data, alternatively we would much rather use the median. The median on the other hand is less likely to be affect by outliers.<br>**
#
# - **Significant change<br>**
# - **Mean increases with high outlier<br>**
# - **Mean decreases with low outlier**

# %% [markdown]
# **For example, if we have the data set {1, 2, 3, 4, 100}, the mean without the outlier (100) is 2.5,<br> but with the outlier, it increases to 22.**

# %% [markdown]
# ### Median:
# **The median is less affected by outliers because it is the middle value of the data set.<br>**
# **The median is the middle value in a set of data when the data is arranged in order of magnitude. If there's an even number of data points, the median is the average of the two middle values. The median is a better measure of central tendency than the mean when there are extreme values, as it is not influenced by outliers.<br>**
#
# **In the same example, the median without the outlier is 2.5, and with the outlier, it is 3.**

# %% [markdown]
# ### Mode:
# **The mode is not affected by outliers as it is the most frequently occurring value in a data set.<br>**
# **It is useful when dealing with categorical data.**

# %% [markdown]
# ### For Measures of Dispersion :
# **The measures of dispersion are used to determine the spread or variability of a dataset. The two most commonly used measures of dispersion are variance and standard deviation.**

# %% [markdown]
# ### Range:
# **Outliers can greatly affect the range because the range is the difference between the highest and lowest values in a data set.<br>**
# **In the example, the range without the outlier is 3, but with the outlier, it increases to 99.**

# %% [markdown]
# ### Variance :
# **Variance is the average of the squared differences from the mean, and it measures how far each data point is from the mean. If the variance is high, the data points are spread out from the mean, and if the variance is low, the data points are clustered around the mean.<br>**
# **Variance is also significantly affected by outliers because it is based on the mean of the data set.nce, indicating a larger spread in the data.<br>**
#
# **For same example, when calculate, the variance is approximately 1522.0 with outlier and Without Outlier it is Variance 1.25.
# The presence of outliers increases the variance, indicating a larger spread in the data.**

# %% [markdown]
# ### Standard Deviation :
# **The standard deviation is the square root of the variance. It is a more commonly used measure of dispersion because it is expressed in the same units as the data, making it easier to interpret. A low standard deviation indicates that the data is tightly clustered around the mean, whereas a high standard deviation indicates that the data is more spread out.<br>**
#
# **Standard Deviation is also significantly affected by outliers because it is based on the variance and mean of the data set. The presence of outliers increases standard deviation, indicating a larger spread in the data.<br>**
#
# **For same example, when calculate,Standard Deviation is approximately 39.01281840626232 with outlier and Without Outlier it is  1.118033988749895. The presence of outliers increases the Standard Deviation, indicating a larger spread in the data.**

# %% [markdown]
# ### Dealing with Outliers:
# **Outliers are extreme values that can significantly affect measures of central tendency and dispersion. To deal with outliers, we can use the interquartile range (IQR). The IQR is the difference between the third quartile (Q3) and the first quartile (Q1). The lower fence is calculated as `Q1 - 1.5*(IQR)`, while the upper fence is calculated as `Q3 + 1.5*(IQR)`. Any data point outside the fences is considered an outlier and can be removed from the dataset.**

# %% [markdown]
# ### Visualizing and Summarizing Data:
# **Boxplots, also known as box and whisker plots, are graphical representations of the five-number summary. They display the minimum and maximum values, the median, and the first and third quartiles as a box with whiskers extending from it. Outliers are represented as individual points outside the whiskers. Boxplots are useful for comparing data across different categories or groups.**
